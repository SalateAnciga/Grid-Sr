# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
#from sklearn.model_selection import train_test_split

# %%
#x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
independent = sc.fit_transform(independent)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'criterion':['mse','mae','friedman_mse'],'max_features':['auto','sqrt','log2'],'splitter':['best','random']}

# %%
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\jegat\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 70 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\jegat\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\jegat\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
# ...

# %%
re=grid.cv_results_

# %%
print("The R_score value of best parameter{}:",format(grid.best_params_))
# Out:
# The R_score value of best parameter{}: {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002632      0.001753         0.000000        0.000000
# 1        0.000000      0.000000         0.000000        0.000000
# 2        0.002679      0.001766         0.000000        0.000000
# 3        0.000018      0.000037         0.000000        0.000000
# 4        0.002697      0.002999         0.000000        0.000000
# 5        0.001004      0.001551         0.000000        0.000000
# 6        0.000808      0.000989         0.000000        0.000000
# 7        0.001603      0.001964         0.000000        0.000000
# 8        0.000803      0.001606         0.000000        0.000000
# 9        0.001206      0.001604         0.000000        0.000000
# 10       0.001116      0.000978         0.000000        0.000000
# 11       0.001067      0.001563         0.000000        0.000000
# 12       0.001178      0.001122         0.000000        0.000000
# ...

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
children_input=int(input("Children"))
sex_input=int(input("Sex Male 0 o 1"))
smoker_yes_input=int(input("Smoker_yes 0 or 1"))
# Out:
# Age 56
# BMI 78
# Children 2
# Sex Male 0 o 1 0
# Smoker_yes 0 or 1 1

# %%
Future_Perdiction=grid.predict([[age_input,bmi_input,children_input,sex_input,smoker_yes_input]])
# Out:
# C:\Users\jegat\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print("Future_perdiction:{}",format(Future_Perdiction))
# Out:
# Future_perdiction:{} [63770.42801]
