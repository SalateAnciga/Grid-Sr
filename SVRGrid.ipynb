# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x_train = sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.svm import SVR

# %%
param_grid={'kernel':['poly','sigmoid','linear','rbf'],'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}

# %%
grid= GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\jegat\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['poly', 'sigmoid', 'linear', 'rbf']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print("The R_score value of best parameter{}:",format(grid.best_params_))
# Out:
# The R_score value of best parameter{}: {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.035106      0.001308         0.007959        0.000237      10
# 1        0.044139      0.003050         0.010474        0.001271      10
# 2        0.036012      0.002655         0.006675        0.001730      10
# 3        0.038680      0.002555         0.020028        0.001705      10
# 4        0.032675      0.002718         0.006789        0.001461      10
# 5        0.044066      0.002774         0.008244        0.000402      10
# 6        0.031667      0.000001         0.006448        0.001964      10
# 7        0.037600      0.001406         0.019510        0.001591      10
# 8        0.036057      0.001749         0.006541        0.001728     100
# 9        0.045645      0.002731         0.009609        0.001352     100
# 10       0.040363      0.001565         0.006849        0.002303     100
# 11       0.041554      0.002045         0.018237        0.001810     100
# 12       0.039314      0.005140         0.008352        0.000883     100
# 13       0.045821      0.002516         0.010546        0.001143     100
# 14       0.039114      0.002565         0.008127        0.000659     100
# 15       0.040875      0.001474         0.019509        0.001079     100
# 16       0.052073      0.004569         0.007756        0.000249    1000
# 17       0.050103      0.003314         0.009452        0.001592    1000
# 18       0.049494      0.001422         0.005046        0.001541    1000
# 19       0.049847      0.001898         0.019413        0.001629    1000
# 20       0.049535      0.002811         0.006928        0.001537    1000
# 21       0.048347      0.004114         0.009052        0.001720    1000
# 22       0.051544      0.003802         0.007458        0.001643    1000
# 23       0.050822      0.001858         0.019838        0.001646    1000
# 24       0.100620      0.038734         0.006257        0.001482    2000
# 25       0.049293      0.004018         0.009166        0.001577    2000
# 26       0.060230      0.004624         0.007543        0.001000    2000
# 27       0.051955      0.000276         0.020038        0.000194    2000
# 28       0.115512      0.102275         0.007634        0.001670    2000
# 29       0.048686      0.003420         0.009141        0.001730    2000
# 30       0.061458      0.004004         0.007023        0.002125    2000
# 31       0.053727      0.001823         0.020207        0.000994    2000
# 32       0.189330      0.120619         0.006540        0.002281    3000
# 33       0.051256      0.002057         0.009144        0.001160    3000
# 34       0.073081      0.013640         0.007154        0.000574    3000
# 35       0.059862      0.004207         0.019613        0.002795    3000
# 36       0.107163      0.025750         0.005727        0.001706    3000
# 37       0.049794      0.003059         0.009045        0.000835    3000
# 38       0.067976      0.010181         0.008269        0.000669    3000
# 39       0.052742      0.003929         0.013795        0.003337    3000
#
#    param_gamma param_kernel  \
# 0         auto         poly
# 1         auto      sigmoid
# 2         auto       linear
# 3         auto          rbf
# 4        scale         poly
# 5        scale      sigmoid
# 6        scale       linear
# 7        scale          rbf
# 8         auto         poly
# 9         auto      sigmoid
# 10        auto       linear
# 11        auto          rbf
# 12       scale         poly
# 13       scale      sigmoid
# 14       scale       linear
# 15       scale          rbf
# 16        auto         poly
# 17        auto      sigmoid
# 18        auto       linear
# 19        auto          rbf
# 20       scale         poly
# 21       scale      sigmoid
# 22       scale       linear
# 23       scale          rbf
# 24        auto         poly
# 25        auto      sigmoid
# 26        auto       linear
# 27        auto          rbf
# 28       scale         poly
# 29       scale      sigmoid
# 30       scale       linear
# 31       scale          rbf
# 32        auto         poly
# 33        auto      sigmoid
# 34        auto       linear
# 35        auto          rbf
# 36       scale         poly
# 37       scale      sigmoid
# 38       scale       linear
# 39       scale          rbf
#
#                                                params  split0_test_score  \
# 0        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.047420
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.044787
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.387624
# 3         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.004176
# 4       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.043648
# 5    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.043946
# 6     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.387624
# 7        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.003956
# 8       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.542212
# 9    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.492088
# 10    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.596232
# 11       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.303414
# 12     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.532310
# 13  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.491855
# 14   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.596232
# 15      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.304939
# 16     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.799185
# 17  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.232428
# 18   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.686126
# 19      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.731430
# 20    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.798212
# 21  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.248266
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.686126
# 23     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.732079
# 24     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.804603
# 25  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.656854
# 26   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.669958
# 27      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.788746
# 28    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.804708
# 29  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.370980
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.669958
# 31     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.789144
# 32     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.804915
# 33  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.795299
# 34   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.669819
# 35      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.795104
# 36    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.805169
# 37  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.651895
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.669819
# 39     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.795353
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.077536          -0.060527          -0.009476
# 1            0.081689          -0.072355          -0.027541
# 2            0.461268           0.288301           0.340540
# 3            0.022594          -0.118956          -0.082926
# 4            0.079780          -0.059229          -0.009498
# 5            0.082230          -0.072132          -0.027546
# 6            0.461268           0.288301           0.340540
# 7            0.022453          -0.119035          -0.082925
# 8            0.566743           0.471172           0.537557
# 9            0.545107           0.438714           0.468576
# 10           0.635776           0.566816           0.588799
# 11           0.319385           0.155546           0.208414
# 12           0.571466           0.474948           0.537506
# 13           0.544604           0.439299           0.468556
# 14           0.635776           0.566816           0.588799
# 15           0.318480           0.155033           0.208422
# 16           0.786769           0.821307           0.810704
# 17           0.306815           0.236688           0.291707
# 18           0.598398           0.586104           0.573860
# 19           0.716349           0.686476           0.710172
# 20           0.787019           0.823118           0.810712
# 21           0.377692           0.315321           0.291779
# 22           0.598398           0.586104           0.573860
# 23           0.715992           0.686057           0.710177
# 24           0.784782           0.847674           0.807280
# 25          -0.432695          -0.346330          -0.484052
# 26           0.592446           0.586953           0.572862
# 27           0.764261           0.818616           0.794131
# 28           0.784713           0.847781           0.807295
# 29          -0.421011          -0.350248          -0.483750
# 30           0.592446           0.586953           0.572862
# 31           0.764022           0.818319           0.794133
# 32           0.783304           0.852190           0.810160
# 33          -1.629662          -1.461919          -1.712710
# 34           0.588893           0.587076           0.572849
# 35           0.772917           0.846181           0.811601
# 36           0.783163           0.852345           0.810160
# 37          -2.010670          -1.468842          -1.712109
# 38           0.588893           0.587076           0.572849
# 39           0.772801           0.846034           0.811601
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.050823         0.000826        0.054025               32
# 1           -0.051470        -0.004978        0.058648               34
# 2            0.297825         0.355112        0.063693               25
# 3           -0.103473        -0.057387        0.056205               35
# 4           -0.050317         0.000877        0.053658               31
# 5           -0.051337        -0.004968        0.058595               33
# 6            0.297825         0.355112        0.063693               25
# 7           -0.103510        -0.057395        0.056230               36
# 8            0.413719         0.506281        0.056081               22
# 9            0.425516         0.474000        0.042447               23
# 10           0.537415         0.585008        0.032600               19
# 11           0.161756         0.229703        0.069348               29
# 12           0.415264         0.506299        0.055077               21
# 13           0.424226         0.473708        0.042461               24
# 14           0.537415         0.585008        0.032600               19
# 15           0.161488         0.229672        0.069604               30
# 16           0.719528         0.787499        0.035885                8
# 17           0.346868         0.282901        0.043415               28
# 18           0.556109         0.600119        0.045217               13
# 19           0.613293         0.691544        0.041718               11
# 20           0.719979         0.787808        0.036003                7
# 21           0.346175         0.315846        0.044478               27
# 22           0.556109         0.600119        0.045217               13
# 23           0.613122         0.691485        0.041876               12
# 24           0.745448         0.797957        0.033268                4
# 25          -0.076409        -0.399268        0.190629               38
# 26           0.556109         0.595666        0.039218               15
# 27           0.709676         0.775086        0.036986                9
# 28           0.745732         0.798046        0.033220                3
# 29          -0.087414        -0.342681        0.135687               37
# 30           0.556109         0.595666        0.039218               15
# 31           0.709586         0.775041        0.036992               10
# 32           0.748175         0.799749        0.034104                2
# 33          -0.929359        -1.505790        0.308601               39
# 34           0.557014         0.595130        0.039068               17
# 35           0.725697         0.790300        0.040188                5
# 36           0.748201         0.799808        0.034165                1
# 37          -0.961821        -1.561068        0.346643               40
# 38           0.557014         0.595130        0.039068               17
# 39           0.725615         0.790281        0.040189                6

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
children_input=int(input("Children"))
sex_input=int(input("Sex Male 0 o 1"))
smoker_yes_input=int(input("Smoker_yes 0 or 1"))
# Out:
# Age 44
# BMI 50
# Children 2
# Sex Male 0 o 1 0
# Smoker_yes 0 or 1 0

# %%
Future_Perdiction=grid.predict([[age_input,bmi_input,children_input,sex_input,smoker_yes_input]])

# %%
print("Future_perdiction:{}",format(Future_Perdiction))
# Out:
# Future_perdiction:{} [12771111.03022632]
