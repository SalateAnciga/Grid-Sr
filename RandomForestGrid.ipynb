# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid={'criterion':['squared_error', 'absolute_error', 'poisson', 'friedman_mse'],'max_features': [None,'sqrt','log2'],'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\jegat\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print("The R_score value of best parameter{}:",format(grid.best_params_))
# Out:
# The R_score value of best parameter{}: {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.033760      0.001161         0.003305        0.000402
# 1        0.283164      0.003386         0.013314        0.002784
# 2        0.031162      0.002426         0.003903        0.000495
# 3        0.231096      0.005023         0.012913        0.001498
# 4        0.025543      0.001053         0.002902        0.000193
# 5        0.229505      0.006549         0.011211        0.000398
# 6        0.109038      0.006186         0.003421        0.000906
# 7        1.061332      0.011666         0.011864        0.000767
# 8        0.068976      0.002838         0.002702        0.000602
# 9        0.631022      0.005868         0.010712        0.000981
# 10       0.065751      0.003290         0.002800        0.000749
# 11       0.635700      0.016406         0.010811        0.000486
# 12       0.033940      0.000804         0.002807        0.000238
# 13       0.314057      0.006770         0.010658        0.000684
# 14       0.026980      0.000972         0.002600        0.000491
# 15       0.249857      0.007844         0.011612        0.000640
# 16       0.027543      0.000833         0.003206        0.000252
# 17       0.255799      0.002205         0.011919        0.000488
# 18       0.033251      0.001374         0.003007        0.000541
# 19       0.288082      0.004613         0.009853        0.001226
# 20       0.026636      0.000960         0.003006        0.000554
# 21       0.231190      0.006928         0.010497        0.000405
# 22       0.026390      0.000946         0.002810        0.000510
# 23       0.181210      0.013388         0.006775        0.000527
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               None                 10
# 1    squared_error               None                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               None                 10
# 7   absolute_error               None                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12         poisson               None                 10
# 13         poisson               None                100
# 14         poisson               sqrt                 10
# 15         poisson               sqrt                100
# 16         poisson               log2                 10
# 17         poisson               log2                100
# 18    friedman_mse               None                 10
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 10
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.797275
# 1   {'criterion': 'squared_error', 'max_features':...           0.806046
# 2   {'criterion': 'squared_error', 'max_features':...           0.804068
# 3   {'criterion': 'squared_error', 'max_features':...           0.802088
# 4   {'criterion': 'squared_error', 'max_features':...           0.794779
# 5   {'criterion': 'squared_error', 'max_features':...           0.807380
# 6   {'criterion': 'absolute_error', 'max_features'...           0.769063
# 7   {'criterion': 'absolute_error', 'max_features'...           0.789153
# 8   {'criterion': 'absolute_error', 'max_features'...           0.770899
# 9   {'criterion': 'absolute_error', 'max_features'...           0.804513
# 10  {'criterion': 'absolute_error', 'max_features'...           0.781222
# 11  {'criterion': 'absolute_error', 'max_features'...           0.797907
# 12  {'criterion': 'poisson', 'max_features': None,...           0.792721
# 13  {'criterion': 'poisson', 'max_features': None,...           0.805124
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.773454
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.804762
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.787435
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.805523
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.795882
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.805265
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.801926
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.804829
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.781922
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.813493
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.715009           0.810765           0.782672
# 1            0.743185           0.832337           0.801442
# 2            0.761515           0.817515           0.816879
# 3            0.760696           0.840967           0.830702
# 4            0.762630           0.833575           0.811471
# 5            0.765255           0.835712           0.830533
# 6            0.762922           0.802986           0.795874
# 7            0.765328           0.816139           0.800339
# 8            0.749134           0.826917           0.822346
# 9            0.763831           0.839150           0.831648
# 10           0.760300           0.820223           0.778867
# 11           0.773285           0.833587           0.830982
# 12           0.749274           0.813928           0.797147
# 13           0.753694           0.836288           0.805129
# 14           0.764012           0.792757           0.809350
# 15           0.771287           0.832830           0.831260
# 16           0.756328           0.816623           0.812283
# 17           0.771859           0.837785           0.830491
# 18           0.727912           0.834608           0.794354
# 19           0.747932           0.839028           0.807154
# 20           0.744165           0.812730           0.807494
# 21           0.770035           0.838369           0.828991
# 22           0.737901           0.821378           0.807589
# 23           0.765584           0.836714           0.835783
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.744910         0.770126        0.035270               24
# 1            0.765467         0.789695        0.031540               13
# 2            0.758879         0.791771        0.026236               11
# 3            0.763117         0.799514        0.033254                7
# 4            0.750733         0.790638        0.030567               12
# 5            0.760471         0.799870        0.031723                5
# 6            0.763494         0.778868        0.017074               21
# 7            0.761911         0.786574        0.020639               14
# 8            0.743719         0.782603        0.035531               19
# 9            0.762940         0.800416        0.032359                4
# 10           0.783696         0.784862        0.019515               16
# 11           0.762680         0.799688        0.028977                6
# 12           0.759649         0.782544        0.024219               20
# 13           0.761039         0.792255        0.030763               10
# 14           0.749908         0.777896        0.021005               22
# 15           0.756610         0.799350        0.030928                8
# 16           0.752757         0.785085        0.026877               15
# 17           0.766408         0.802413        0.029255                1
# 18           0.764515         0.783454        0.035591               18
# 19           0.763496         0.792575        0.032772                9
# 20           0.755479         0.784359        0.028630               17
# 21           0.760062         0.800457        0.031074                3
# 22           0.735496         0.776857        0.035159               23
# 23           0.756670         0.801649        0.034231                2

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
children_input=int(input("Children"))
sex_input=int(input("Sex Male 0 or 1"))
smoker_yes_input=int(input("Smoker_yes 0 or 1"))
# Out:
# Age 44
# BMI 50
# Children 2
# Sex Male 0 or 1 0
# Smoker_yes 0 or 1 0

# %%
Future_Perdiction=grid.predict([[age_input,bmi_input,children_input,sex_input,smoker_yes_input]])

# %%
print("Future_perdiction:{}",format(Future_Perdiction))
# Out:
# Future_perdiction:{} [15236.8598734]
