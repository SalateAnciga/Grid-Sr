# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import os

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
#from sklearn.model_selection import train_test_split

# %%
#x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
independent=sc.fit_transform(independent)

# %%
independent
# Out:
# array([[-1.43876426, -0.45332   , -0.90861367, -1.0105187 ,  1.97058663],
#        [-1.50996545,  0.5096211 , -0.07876719,  0.98959079, -0.5074631 ],
#        [-0.79795355,  0.38330685,  1.58092576,  0.98959079, -0.5074631 ],
#        ...,
#        [-1.50996545,  1.0148781 , -0.90861367, -1.0105187 , -0.5074631 ],
#        [-1.29636188, -0.79781341, -0.90861367, -1.0105187 , -0.5074631 ],
#        [ 1.55168573, -0.26138796, -0.90861367, -1.0105187 ,  1.97058663]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid={'criterion':['squared_error', 'absolute_error', 'poisson', 'friedman_mse'],'max_features': [None,'sqrt','log2'],'n_estimators':[10,100]}

# %%
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
#regressor=grid.fit(independent,dependent)
#y_pred=regressor.predict(independent)
#y_pred

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\jegat\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print("The R_score value of best parameter{}:",format(grid.best_params_))
# Out:
# The R_score value of best parameter{}: {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.045425      0.001384         0.003410        0.000374
# 1        0.417704      0.014281         0.015235        0.002035
# 2        0.040688      0.003782         0.003441        0.000584
# 3        0.310773      0.004956         0.015530        0.001437
# 4        0.035014      0.002417         0.003855        0.000369
# 5        0.344320      0.012432         0.015227        0.000810
# 6        0.204660      0.004786         0.002906        0.000504
# 7        1.685469      0.383543         0.009973        0.001077
# 8        0.122431      0.005823         0.003182        0.000754
# 9        1.129420      0.076761         0.012357        0.001458
# 10       0.119034      0.005896         0.003451        0.000551
# 11       1.117348      0.087049         0.012393        0.002437
# 12       0.046695      0.002346         0.003097        0.000667
# 13       0.486041      0.015868         0.015009        0.002278
# 14       0.039218      0.002444         0.003827        0.001061
# 15       0.359457      0.013531         0.015924        0.003097
# 16       0.043221      0.002654         0.003414        0.000525
# 17       0.340835      0.015652         0.014824        0.001216
# 18       0.052009      0.005244         0.003837        0.000628
# 19       0.405363      0.007047         0.015902        0.002464
# 20       0.037605      0.004814         0.003606        0.000978
# 21       0.316647      0.011523         0.014467        0.001285
# 22       0.038360      0.003399         0.003012        0.000718
# 23       0.258861      0.013009         0.010245        0.001253
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               None                 10
# 1    squared_error               None                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               None                 10
# 7   absolute_error               None                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12         poisson               None                 10
# 13         poisson               None                100
# 14         poisson               sqrt                 10
# 15         poisson               sqrt                100
# 16         poisson               log2                 10
# 17         poisson               log2                100
# 18    friedman_mse               None                 10
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 10
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.842970
# 1   {'criterion': 'squared_error', 'max_features':...           0.846239
# 2   {'criterion': 'squared_error', 'max_features':...           0.836821
# 3   {'criterion': 'squared_error', 'max_features':...           0.858794
# 4   {'criterion': 'squared_error', 'max_features':...           0.839590
# 5   {'criterion': 'squared_error', 'max_features':...           0.861002
# 6   {'criterion': 'absolute_error', 'max_features'...           0.828652
# 7   {'criterion': 'absolute_error', 'max_features'...           0.840041
# 8   {'criterion': 'absolute_error', 'max_features'...           0.849161
# 9   {'criterion': 'absolute_error', 'max_features'...           0.857502
# 10  {'criterion': 'absolute_error', 'max_features'...           0.836014
# 11  {'criterion': 'absolute_error', 'max_features'...           0.857397
# 12  {'criterion': 'poisson', 'max_features': None,...           0.832699
# 13  {'criterion': 'poisson', 'max_features': None,...           0.852834
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.852930
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860673
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.844017
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.857060
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.855473
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.848273
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.847802
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.856169
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.845331
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.858036
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.741869           0.850898           0.803273
# 1            0.773948           0.856762           0.823933
# 2            0.759919           0.850474           0.819957
# 3            0.783823           0.859121           0.825632
# 4            0.759264           0.855359           0.815104
# 5            0.778145           0.861888           0.828361
# 6            0.751164           0.856376           0.806092
# 7            0.772220           0.851714           0.821667
# 8            0.758763           0.844292           0.804673
# 9            0.781849           0.859671           0.829735
# 10           0.757145           0.843148           0.812132
# 11           0.784342           0.858040           0.822284
# 12           0.766783           0.846551           0.804608
# 13           0.772194           0.856435           0.815865
# 14           0.744958           0.852210           0.817697
# 15           0.781263           0.863319           0.830167
# 16           0.771385           0.860932           0.816630
# 17           0.783469           0.859730           0.827251
# 18           0.762883           0.836063           0.803120
# 19           0.778166           0.856511           0.819331
# 20           0.767295           0.829634           0.819152
# 21           0.785070           0.857228           0.831036
# 22           0.777855           0.839939           0.818120
# 23           0.782902           0.859468           0.827315
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.830186         0.813839        0.039447               23
# 1            0.838918         0.827960        0.029042               10
# 2            0.827696         0.818974        0.031226               17
# 3            0.839090         0.833292        0.027774                6
# 4            0.822003         0.818264        0.032667               18
# 5            0.839975         0.833874        0.030640                5
# 6            0.820087         0.812474        0.034776               24
# 7            0.840808         0.825290        0.028235               12
# 8            0.822063         0.815791        0.032683               21
# 9            0.845090         0.834769        0.028528                2
# 10           0.836452         0.816978        0.031718               19
# 11           0.841597         0.832732        0.027489                8
# 12           0.832102         0.816549        0.028363               20
# 13           0.842040         0.827874        0.031253               11
# 14           0.833837         0.820326        0.039873               15
# 15           0.844580         0.836000        0.029862                1
# 16           0.812615         0.821116        0.030579               14
# 17           0.837599         0.833022        0.027571                7
# 18           0.837448         0.818997        0.032751               16
# 19           0.838832         0.828223        0.027927                9
# 20           0.814912         0.815759        0.026759               22
# 21           0.841909         0.834283        0.026443                4
# 22           0.831483         0.822546        0.024160               13
# 23           0.843955         0.834335        0.028216                3

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
children_input=int(input("Children"))
sex_input=int(input("Sex Male 0 or 1"))
smoker_yes_input=int(input("Smoker_yes 0 or 1"))
# Out:
# Age 44
# BMI 50
# Children 2
# Sex Male 0 or 1 0
# Smoker_yes 0 or 1 0

# %%
Future_Perdiction=grid.predict([[age_input,bmi_input,children_input,sex_input,smoker_yes_input]])

# %%
print("Future_perdiction:{}",format(Future_Perdiction))
# Out:
# Future_perdiction:{} [15890.9275864]
