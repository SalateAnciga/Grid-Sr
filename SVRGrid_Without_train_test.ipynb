# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
independent = sc.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.svm import SVR

# %%
param_grid={'kernel':['poly','sigmoid','linear','rbf'],'C':[10,100,1000,2000,3000],'gamma':['auto','scale']}

# %%
grid= GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\jegat\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['poly', 'sigmoid', 'linear', 'rbf']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
print("The R_score value of best parameter{}:",format(grid.best_params_))
# Out:
# The R_score value of best parameter{}: {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.080211      0.010274         0.014165        0.001577      10
# 1        0.111878      0.023575         0.017681        0.003026      10
# 2        0.111463      0.023436         0.013351        0.001595      10
# 3        0.095072      0.015296         0.040823        0.001492      10
# 4        0.080015      0.007702         0.013649        0.002720      10
# 5        0.103142      0.017150         0.017487        0.002295      10
# 6        0.074162      0.003335         0.014770        0.001165      10
# 7        0.087827      0.004278         0.042237        0.001648      10
# 8        0.082500      0.004514         0.013767        0.001589     100
# 9        0.102134      0.002987         0.017606        0.001331     100
# 10       0.081302      0.002465         0.012804        0.001720     100
# 11       0.091517      0.003788         0.042211        0.001375     100
# 12       0.086187      0.010184         0.014875        0.001629     100
# 13       0.097967      0.003289         0.017902        0.001058     100
# 14       0.082945      0.002427         0.014096        0.001890     100
# 15       0.088508      0.002652         0.041092        0.000667     100
# 16       0.117650      0.012858         0.013857        0.001624    1000
# 17       0.104482      0.004595         0.017970        0.002180    1000
# 18       0.102355      0.001835         0.013373        0.002011    1000
# 19       0.098593      0.002686         0.042667        0.002618    1000
# 20       0.115604      0.011044         0.013965        0.002218    1000
# 21       0.110445      0.007635         0.016974        0.001658    1000
# 22       0.101819      0.003395         0.012755        0.001301    1000
# 23       0.099717      0.001862         0.039360        0.001638    1000
# 24       0.169017      0.055866         0.014067        0.001689    2000
# 25       0.107747      0.001824         0.018478        0.001665    2000
# 26       0.123941      0.004514         0.012248        0.000748    2000
# 27       0.110118      0.003989         0.042437        0.003205    2000
# 28       0.154467      0.023313         0.014748        0.001665    2000
# 29       0.110496      0.003341         0.017491        0.001178    2000
# 30       0.122058      0.002383         0.013359        0.001565    2000
# 31       0.110073      0.001225         0.045344        0.003404    2000
# 32       0.274201      0.137336         0.011738        0.001811    3000
# 33       0.111134      0.005052         0.017092        0.001161    3000
# 34       0.142488      0.005237         0.014059        0.002442    3000
# 35       0.127508      0.010046         0.042044        0.001944    3000
# 36       0.217826      0.047078         0.011964        0.002662    3000
# 37       0.115436      0.011926         0.018189        0.001380    3000
# 38       0.141168      0.010688         0.012034        0.003044    3000
# 39       0.109021      0.012045         0.031433        0.005571    3000
#
#    param_gamma param_kernel  \
# 0         auto         poly
# 1         auto      sigmoid
# 2         auto       linear
# 3         auto          rbf
# 4        scale         poly
# 5        scale      sigmoid
# 6        scale       linear
# 7        scale          rbf
# 8         auto         poly
# 9         auto      sigmoid
# 10        auto       linear
# 11        auto          rbf
# 12       scale         poly
# 13       scale      sigmoid
# 14       scale       linear
# 15       scale          rbf
# 16        auto         poly
# 17        auto      sigmoid
# 18        auto       linear
# 19        auto          rbf
# 20       scale         poly
# 21       scale      sigmoid
# 22       scale       linear
# 23       scale          rbf
# 24        auto         poly
# 25        auto      sigmoid
# 26        auto       linear
# 27        auto          rbf
# 28       scale         poly
# 29       scale      sigmoid
# 30       scale       linear
# 31       scale          rbf
# 32        auto         poly
# 33        auto      sigmoid
# 34        auto       linear
# 35        auto          rbf
# 36       scale         poly
# 37       scale      sigmoid
# 38       scale       linear
# 39       scale          rbf
#
#                                                params  split0_test_score  \
# 0        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.037227
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.029301
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.487873
# 3         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.050402
# 4       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.039041
# 5    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.029716
# 6     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.487873
# 7        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.050517
# 8       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.650669
# 9    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.531459
# 10    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.641464
# 11       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.360724
# 12     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.654011
# 13  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.527367
# 14   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.641464
# 15      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.360068
# 16     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.848655
# 17  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.170988
# 18   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.672679
# 19      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.833468
# 20    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.848927
# 21  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.161027
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.672679
# 23     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.833330
# 24     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.851467
# 25  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.377095
# 26   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.671545
# 27      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.863090
# 28    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.851782
# 29  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.075530
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.671545
# 31     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.863070
# 32     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.852383
# 33  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -3.510085
# 34   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.668269
# 35      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.870252
# 36    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.852350
# 37  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -3.433129
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.668269
# 39     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.870230
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.042884           0.065672           0.041406
# 1            0.043379           0.060402           0.040689
# 2            0.472341           0.485102           0.475835
# 3           -0.045276          -0.016737          -0.041345
# 4            0.040111           0.063362           0.042506
# 5            0.042770           0.059852           0.040918
# 6            0.472341           0.485102           0.475835
# 7           -0.045096          -0.016601          -0.041415
# 8            0.616836           0.642137           0.615462
# 9            0.492180           0.518726           0.511646
# 10           0.601994           0.627339           0.628877
# 11           0.347206           0.361437           0.343682
# 12           0.612976           0.636708           0.617573
# 13           0.490754           0.520064           0.511215
# 14           0.601994           0.627339           0.628877
# 15           0.348158           0.362312           0.343255
# 16           0.774485           0.868188           0.805521
# 17          -0.021689           0.135578           0.120185
# 18           0.620927           0.730011           0.632260
# 19           0.754793           0.802307           0.777257
# 20           0.774567           0.868177           0.805541
# 21           0.099347           0.157690           0.184345
# 22           0.620927           0.730011           0.632260
# 23           0.754986           0.802746           0.777131
# 24           0.773953           0.868926           0.807826
# 25          -1.487236          -1.402559          -1.330143
# 26           0.618499           0.728708           0.627927
# 27           0.775949           0.848369           0.801411
# 28           0.774049           0.868717           0.807810
# 29          -1.732497          -1.358992          -1.172710
# 30           0.618499           0.728708           0.627927
# 31           0.775993           0.848544           0.801377
# 32           0.773067           0.868612           0.806641
# 33          -4.162603          -3.787697          -3.774905
# 34           0.618040           0.728704           0.627698
# 35           0.781886           0.855146           0.806056
# 36           0.773058           0.868576           0.806808
# 37          -4.040316          -3.681947          -3.469604
# 38           0.618040           0.728704           0.627698
# 39           0.781912           0.855341           0.806008
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.034393         0.044316        0.011093               32
# 1            0.017824         0.038319        0.014285               33
# 2            0.447692         0.473769        0.014239               25
# 3           -0.048491        -0.040450        0.012248               36
# 4            0.036594         0.044323        0.009707               31
# 5            0.018234         0.038298        0.013912               34
# 6            0.447692         0.473769        0.014239               25
# 7           -0.048600        -0.040446        0.012321               35
# 8            0.606497         0.626320        0.016993               19
# 9            0.486503         0.508103        0.016679               23
# 10           0.596234         0.619182        0.017199               21
# 11           0.333290         0.349268        0.010678               27
# 12           0.608877         0.626029        0.016930               20
# 13           0.485494         0.506979        0.016308               24
# 14           0.596234         0.619182        0.017199               21
# 15           0.332521         0.349263        0.010997               28
# 16           0.808550         0.821080        0.033316                8
# 17           0.099719         0.100956        0.065599               30
# 18           0.691909         0.669557        0.039799               13
# 19           0.783844         0.790334        0.026383               12
# 20           0.808535         0.821149        0.033334                7
# 21           0.077914         0.136065        0.040377               29
# 22           0.691909         0.669557        0.039799               13
# 23           0.783512         0.790341        0.026356               11
# 24           0.814939         0.823422        0.033525                4
# 25          -1.162566        -1.351920        0.107552               38
# 26           0.691027         0.667541        0.040702               15
# 27           0.812077         0.820179        0.031655               10
# 28           0.815101         0.823492        0.033486                3
# 29          -1.199166        -1.307779        0.231079               37
# 30           0.691027         0.667541        0.040702               15
# 31           0.812016         0.820200        0.031676                9
# 32           0.816036         0.823348        0.033919                6
# 33          -3.088834        -3.664825        0.355164               40
# 34           0.688847         0.666312        0.040560               17
# 35           0.823614         0.827391        0.032086                2
# 36           0.816178         0.823394        0.033884                5
# 37          -3.179970        -3.560993        0.287840               39
# 38           0.688847         0.666312        0.040560               17
# 39           0.823606         0.827419        0.032113                1

# %%
age_input=float(input("Age"))
bmi_input=float(input("BMI"))
children_input=int(input("Children"))
sex_input=int(input("Sex Male 0 o 1"))
smoker_yes_input=int(input("Smoker_yes 0 or 1"))
# Out:
# Age 34
# BMI 65
# Children 1
# Sex Male 0 o 1 0
# Smoker_yes 0 or 1 1

# %%
Future_Perdiction=grid.predict([[age_input,bmi_input,children_input,sex_input,smoker_yes_input]])

# %%
Future_Perdiction
# Out:
# array([17144.08729473])
